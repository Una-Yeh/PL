# %%
import requests 
import json
import time
from time import sleep
import pandas as pd

# %%
# https://www.lawplus.com.tw/#/searchReport?query=%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585
# https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585)
# 上面的是原本的網址 ,下面的是可以轉換成json的網址(裁判家自帶)

urlfirst = "https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585)"
urlfirst
# Out:
# 'https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585)'

# %%
res = requests.get(urlfirst,verify=False)
res
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.lawplus.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <Response [200]>

# %%
res.text
# Out:
# '{"page":1,"records":228849,"rows":[{"caseNum":"95,國,2","caseType":"V","content":"臺灣宜蘭地方法院民事判決\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 95年度國字第2號\\r\\n原\u3000\u3000\u3000告\u3000乙○○\\r\\n訴訟代理人\u3000楊德海律師\\r\\n被\u3000\u3000\u3000告\u3000宜蘭縣警察局\\r\\n法定代理人\u3000丙○○\\r\\n訴訟代理人\u3000陳為祥律師\\r\\n上列當事人間...","court":"","identifier":"ILDV,95,國,2,20070413,2-2e707cf8-bee6-40b6-935e-db8bd1670965","issue":"國家賠償","jtype":"J","judgeDate":"2007/04/13","litigant":null,"tags":null,"title":"ILDV,95,國,2,20070413,2-2e707cf8-bee6-40b6-935e-db8bd1670965","type":"民事判決"},{"caseNum":"100,訴,5114","caseType":"V","content":"臺灣臺北地方法院民事判決\u3000\u3000\u3000\u3000\u3000\u3000 100年度訴字第5114號\\r\\n原\u3000\u3000\u3000告\u3000薛明吉\\r\\n訴訟代理人\u3000薛子涵\\r\\n原\u3000\u3000\u3000告\u3000張琇裡\\r\\n被\u3000\u3000\u3000告\u3000財團法人汽車交通事故特別補償基金\\r\\n法定代理人\u3000吳當傑...","court":"","identifier":"TPDV,100,訴,5114,20120531,1-94387f93-9719-4b65-a22e-137ac502e508","issue":"給付補償金","jtype":"J","judgeDate":"2012/05/31","litigant":null,"tags":
# ...

# %%
# 用json顯示
data = json.loads(res.text)
data
# Out:
# {'page': 1,
#  'records': 228849,
#  'rows': [{'caseNum': '95,國,2',
#    'caseType': 'V',
#    'content': '臺灣宜蘭地方法院民事判決\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 95年度國字第2號\r\n原\u3000\u3000\u3000告\u3000乙○○\r\n訴訟代理人\u3000楊德海律師\r\n被\u3000\u3000\u3000告\u3000宜蘭縣警察局\r\n法定代理人\u3000丙○○\r\n訴訟代理人\u3000陳為祥律師\r\n上列當事人間...',
#    'court': '',
#    'identifier': 'ILDV,95,國,2,20070413,2-2e707cf8-bee6-40b6-935e-db8bd1670965',
#    'issue': '國家賠償',
#    'jtype': 'J',
#    'judgeDate': '2007/04/13',
#    'litigant': None,
#    'tags': None,
#    'title': 'ILDV,95,國,2,20070413,2-2e707cf8-bee6-40b6-935e-db8bd1670965',
#    'type': '民事判決'},
#   {'caseNum': '100,訴,5114',
#    'caseType': 'V',
#    'content': '臺灣臺北地方法院民事判決\u3000\u3000\u3000\u3000\u3000\u3000 100年度訴字第5114號\r\n原\u3000\u3000\u3000告\u3000薛明吉\r\n訴訟代理人\u3000薛子涵\r\n原\u3000\u3000\u3000告\u3000張琇裡\r\n被\u3000\u3000\u3000告\u3000財團法人汽車交通事故特別補償基金\r\n法定代理人\u3000吳當傑...',
#    'court': '',
# ...
